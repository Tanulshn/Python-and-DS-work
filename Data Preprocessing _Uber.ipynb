# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
sns.set(color_codes = True) # adds a nice color background to the graph
# %matplotlib inline

# %%
uber = pd.read_csv('uberdrive.csv')

# %%
uber
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
a= uber.isnull()
a
# Out:
#       START_DATE*  END_DATE*  CATEGORY*  START*  STOP*  MILES*  PURPOSE*
# 0           False      False      False   False  False   False     False
# 1           False      False      False   False  False   False      True
# 2           False      False      False   False  False   False     False
# 3           False      False      False   False  False   False     False
# 4           False      False      False   False  False   False     False
# ...           ...        ...        ...     ...    ...     ...       ...
# 1151        False      False      False   False  False   False     False
# 1152        False      False      False   False  False   False     False
# 1153        False      False      False   False  False   False     False
# 1154        False      False      False   False  False   False     False
# 1155        False       True       True    True   True   False      True
#
# [1156 rows x 7 columns]

# %%
uber.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
uber.describe().T
# Out:
#          count       mean         std  min  25%  50%   75%      max
# MILES*  1156.0  21.115398  359.299007  0.5  2.9  6.0  10.4  12204.7

# %%
# Q2

print(uber.head(10))
print(' ')
#Q1
print(uber.tail(10))
# Out:
#         START_DATE*         END_DATE* CATEGORY*           START*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business      Fort Pierce
# 5  01-06-2016 17:15  01-06-2016 17:19  Business  West Palm Beach
# 6  01-06-2016 17:30  01-06-2016 17:35  Business  West Palm Beach
# 7  01-07-2016 13:27  01-07-2016 13:33  Business             Cary
# 8  01-10-2016 08:05  01-10-2016 08:25  Business             Cary
# 9  01-10-2016 12:17  01-10-2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# ...

# %%
len(uber), len(uber.columns)
# Out:
# (1156, 7)

# %%
uber.shape
# Out:
# (1156, 7)

# %%
uber.size
# Out:
# 8092

# %%
len(uber)* len(uber.columns)
# Out:
# 8092

# %%
len(uber.columns)
# Out:
# 7

# %%
uber.isnull()
# Out:
#       START_DATE*  END_DATE*  CATEGORY*  START*  STOP*  MILES*  PURPOSE*
# 0           False      False      False   False  False   False     False
# 1           False      False      False   False  False   False      True
# 2           False      False      False   False  False   False     False
# 3           False      False      False   False  False   False     False
# 4           False      False      False   False  False   False     False
# ...           ...        ...        ...     ...    ...     ...       ...
# 1151        False      False      False   False  False   False     False
# 1152        False      False      False   False  False   False     False
# 1153        False      False      False   False  False   False     False
# 1154        False      False      False   False  False   False     False
# 1155        False       True       True    True   True   False      True
#
# [1156 rows x 7 columns]

# %%
uber.nunique()
# Out:
# START_DATE*    1155
# END_DATE*      1154
# CATEGORY*         2
# START*          176
# STOP*           187
# MILES*          257
# PURPOSE*         10
# dtype: int64

# %%
uber['STOP*'].nunique()
# Out:
# 187

# %%
uber[uber['START*'] == 'San Francisco']
# Out:
#           START_DATE*         END_DATE* CATEGORY*         START*       STOP*  \
# 362  05-09-2016 14:39  05-09-2016 15:06  Business  San Francisco   Palo Alto
# 440   6/14/2016 16:09   6/14/2016 16:39  Business  San Francisco  Emeryville
# 836  10/19/2016 14:02  10/19/2016 14:31  Business  San Francisco    Berkeley
# 917  11-07-2016 19:17  11-07-2016 19:57  Business  San Francisco    Berkeley
# 919  11-08-2016 12:16  11-08-2016 12:49  Business  San Francisco    Berkeley
# 927  11-09-2016 18:40  11-09-2016 19:17  Business  San Francisco     Oakland
# 933  11-10-2016 15:17  11-10-2016 15:22  Business  San Francisco     Oakland
# 966  11/15/2016 20:44  11/15/2016 21:00  Business  San Francisco    Berkeley
#
#      MILES*         PURPOSE*
# 362    20.5  Between Offices
# 440    11.6          Meeting
# 836    10.8              NaN
# 917    13.2  Between Offices
# 919    11.3          Meeting
# 927    12.7   Customer Visit
# 933     9.9   Temporary Site
# 966    11.8   Temporary Site

# %%
a=uber['START*'].value_counts()
a[0]
# Out:
# 201

# %%
uber['STOP*'].value_counts()
# Out:
# Cary                    203
# Unknown Location        149
# Morrisville              84
# Whitebridge              65
# Islamabad                58
#                        ...
# Wake Forest               1
# Soho                      1
# Fuquay-Varina             1
# Isles of Buena Vista      1
# Palm Beach                1
# Name: STOP*, Length: 187, dtype: int64

# %%
uber['STOP*'].value_counts()
# Out:
# Cary                    203
# Unknown Location        149
# Morrisville              84
# Whitebridge              65
# Islamabad                58
#                        ...
# Wake Forest               1
# Soho                      1
# Fuquay-Varina             1
# Isles of Buena Vista      1
# Palm Beach                1
# Name: STOP*, Length: 187, dtype: int64

# %%
uber
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
uber
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
p = uber[uber['START*'] == 'San Francisco']
p
# Out:
#           START_DATE*         END_DATE* CATEGORY*         START*       STOP*  \
# 362  05-09-2016 14:39  05-09-2016 15:06  Business  San Francisco   Palo Alto
# 440   6/14/2016 16:09   6/14/2016 16:39  Business  San Francisco  Emeryville
# 836  10/19/2016 14:02  10/19/2016 14:31  Business  San Francisco    Berkeley
# 917  11-07-2016 19:17  11-07-2016 19:57  Business  San Francisco    Berkeley
# 919  11-08-2016 12:16  11-08-2016 12:49  Business  San Francisco    Berkeley
# 927  11-09-2016 18:40  11-09-2016 19:17  Business  San Francisco     Oakland
# 933  11-10-2016 15:17  11-10-2016 15:22  Business  San Francisco     Oakland
# 966  11/15/2016 20:44  11/15/2016 21:00  Business  San Francisco    Berkeley
#
#      MILES*         PURPOSE*
# 362    20.5  Between Offices
# 440    11.6          Meeting
# 836    10.8              NaN
# 917    13.2  Between Offices
# 919    11.3          Meeting
# 927    12.7   Customer Visit
# 933     9.9   Temporary Site
# 966    11.8   Temporary Site

# %%
len(p), len(p.columns)
# Out:
# (8, 7)

# %%
uber['PURPOSE*'].unique().tolist()
# Out:
# ['Meal/Entertain',
#  nan,
#  'Errand/Supplies',
#  'Meeting',
#  'Customer Visit',
#  'Temporary Site',
#  'Between Offices',
#  'Charity ($)',
#  'Commute',
#  'Moving',
#  'Airport/Travel']

# %%
len(uber['PURPOSE*'].unique().tolist())
# Out:
# 11

# %%
a = uber.groupby(['START*','STOP*']).size().reset_index(name= 'Times')
a
# Out:
#             START*               STOP*  Times
# 0            Agnew               Agnew      1
# 1            Agnew                Cory      1
# 2            Agnew         Renaissance      2
# 3           Almond         Bryson City      1
# 4             Apex                Apex      2
# ..             ...                 ...    ...
# 356    Whitebridge         Wayne Ridge      4
# 357    Whitebridge      Westpark Place     14
# 358    Whitebridge         Whitebridge      7
# 359    Whitebridge  Williamsburg Manor      1
# 360  Winston Salem           Asheville      1
#
# [361 rows x 3 columns]

# %%
a.sort_values(by= ['Times'], ascending = False,inplace = True)
a
# Out:
#                START*             STOP*  Times
# 318  Unknown Location  Unknown Location     86
# 203       Morrisville              Cary     75
# 46               Cary       Morrisville     67
# 40               Cary              Cary     53
# 42               Cary            Durham     36
# ..                ...               ...    ...
# 131           Houston        Sugar Land      1
# 129           Houston         Galveston      1
# 127    Heritage Pines       Whitebridge      1
# 126    Heritage Pines    Edgehill Farms      1
# 360     Winston Salem         Asheville      1
#
# [361 rows x 3 columns]

# %%
a.to_csv('Start1.csv',index= False)

# %%
print(' The dimension of the dataset are', uber.shape[0], 'Rows and', uber.shape[1],' Columns')
# Out:
#  The dimension of the dataset are 1156 Rows and 7  Columns

# %%
uber.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
uber.isnull().sum().reset_index(name= 'No of missing values')
# Out:
#          index  No of missing values
# 0  START_DATE*                     0
# 1    END_DATE*                     1
# 2    CATEGORY*                     1
# 3       START*                     1
# 4        STOP*                     1
# 5       MILES*                     0
# 6     PURPOSE*                   503

# %%
df =uber.dropna()
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# 5     01-06-2016 17:15  01-06-2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
q17['NEW'] = df[['START*'and'STOP*']].count()
q17
# Out:
# START*                          131
# STOP*                           137
# NEW       STOP*    653
# dtype: int64
# dtype: object

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# 5     01-06-2016 17:15  01-06-2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
stop = df['STOP*']
start = df['START*']

# %%
new = pd.concat([stop, start], axis =1)
new['Start - Stop']= start+'-'+stop
new
# Out:
#                  STOP*            START*                       Start - Stop
# 0          Fort Pierce       Fort Pierce            Fort Pierce-Fort Pierce
# 2          Fort Pierce       Fort Pierce            Fort Pierce-Fort Pierce
# 3          Fort Pierce       Fort Pierce            Fort Pierce-Fort Pierce
# 4      West Palm Beach       Fort Pierce        Fort Pierce-West Palm Beach
# 5      West Palm Beach   West Palm Beach    West Palm Beach-West Palm Beach
# ...                ...               ...                                ...
# 1150           Karachi           Karachi                    Karachi-Karachi
# 1151  Unknown Location           Karachi           Karachi-Unknown Location
# 1152  Unknown Location  Unknown Location  Unknown Location-Unknown Location
# 1153           Gampaha        Katunayake                 Katunayake-Gampaha
# 1154         Ilukwatta           Gampaha                  Gampaha-Ilukwatta
#
# [653 rows x 3 columns]

# %%
new['Start - Stop'].value_counts()
# Out:
# Cary-Morrisville                     52
# Morrisville-Cary                     51
# Cary-Cary                            44
# Cary-Durham                          30
# Unknown Location-Unknown Location    30
#                                      ..
# East Austin-West University           1
# Colombo-Nugegoda                      1
# Emeryville-Oakland                    1
# Rawalpindi-Islamabad                  1
# Burtrose-Whitebridge                  1
# Name: Start - Stop, Length: 239, dtype: int64
